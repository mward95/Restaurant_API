# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from census import Census
from pprint import pprint
# import gmaps

# Google API Key
from config import gkey

# %%
# geocoordinates

target_coordinates = "33.753746, -84.386330"
# target_coordinates = "43.6187102, -116.2146068"
target_search = "mexican"
# meters is the units
target_radius = 1000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

frame_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=input=location=33.753746%2C+-84.386330&keyword=mexican&radius=1000&type=restaurant&key=AIzaSyCt3iZn02ZXST9uTFioz5cxC4wp5KiXLK0"  

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.753746%2C+-84.386330&keyword=mexican&radius=1000&type=restaurant&key=AIzaSyCt3iZn02ZXST9uTFioz5cxC4wp5KiXLK0

# %%
# convert response to json
places_data = response.json()
    
# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# places_data_json = pd.read_json('base_url')
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7557132,
#                     "lng": -84.38966719999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.75699282989272,
#                         "lng": -84.38827992010728
#                     },
#                     "southwest": {
#                         "lat": 33.75429317010728,
#                         "lng": -84.39097957989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Taqueria on Broad",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101092625766479055954\">Jessica M</a>"
#                     ],
#                     "photo_reference": "Aap_uEBUFqHS0xh5y8lb7WzsCAtN7I5zmWJmBJuA7FEgckDRFk0IHw9yccXVQamFf0tey4FwFpCtxR76ox11NHjIdswuJuAXO6tCX0L891lWJTctB8c2KLBJhs9X_rBqtPXF1SFupW7QNKqarvA_WDj2EcwZ2b-P1yszS5kgCuO8KWSIoeST",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJf1Fz4IYD9YgRDmz-XkMLzjY",
#             "plus_code": {
#                 "compound_code": "QJ46+74 Atlanta, Georgia",
#                 "global_code": "865QQJ46+74"
#             },
#             "price_level": 1,
#             "rating": 4.6,
#             "reference": "ChIJf1Fz4IYD9YgRDmz-XkMLzjY",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 391,
#             "vicinity": "54 Broad St NW, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7590348,
#                     "lng": -84.386686
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.76017502989272,
#                         "lng": -84.3853305
#                     },
#                     "southwest": {
#                         "lat": 33.75747537010728,
#                         "lng": -84.3883405
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Alma Cocina Downtown",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105648610797534600760\">Devon Smith</a>"
#                     ],
#                     "photo_reference": "Aap_uEAtOTsLyRuuNntqlxDDQ-KgB2iSiaOWFZGW9XHGzINZdWZyIjM4Pvs_GKwuGIgB4dBM3p9bFsIhs23ngevPhjv82L_Y8niQWmNYzvjnUJbH8ETJpA2VAn5bIwMNTeYcdI1hhEb7DhXm5ie4fNGoQ_dgar9emat7_LuSliG07SaPRO0g",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJSd4kc3gE9YgRq6HkvZcW-cw",
#             "plus_code": {
#                 "compound_code": "QJ57+J8 Atlanta, Georgia",
#                 "global_code": "865QQJ57+J8"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJSd4kc3gE9YgRq6HkvZcW-cw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "bar",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1677,
#             "vicinity": "191 Peachtree St NE, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7619706,
#                     "lng": -84.39528299999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.76317802989271,
#                         "lng": -84.39406697010727
#                     },
#                     "southwest": {
#                         "lat": 33.76047837010726,
#                         "lng": -84.39676662989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Dos Bocas",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/
",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ75c7-4MD9YgR1MMUlsZdObU",
#             "plus_code": {
#                 "compound_code": "QJ46+79 Atlanta, Georgia",
#                 "global_code": "865QQJ46+79"
#             },
#             "price_level": 1,
#             "rating": 3.4,
#             "reference": "ChIJ75c7-4MD9YgR1MMUlsZdObU",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 331,
#             "vicinity": "70 Peachtree St, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7616709,
#                     "lng": -84.3951127
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.76306357989272,
#                         "lng": -84.39363957010728
#                     },
#                     "southwest": {
#                         "lat": 33.76036392010727,
#                         "lng": -84.39633922989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Baja Fresh Mexican Grill",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 344,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106199545881672910553\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDTOdlYgk41osoQPfSZYg7vb0lPxGWOMCx2TlisZ4_oC5zJFzsc64bFFwbD2joLDHhMVnuKUhaIe7F29lpVbnhCHaE8KgZDQCVfhAunE0bCCgBDEZlYjcgbXq4Xzmj2PODNYS4MjwcZPxzR7PaP_kpFhxTJG1GNDAOzrvlAHL5fDKJb",
#                     "width": 666
#                 }
#             ],
#             "place_id": "ChIJpdHfNH4E9YgRvdYHU9RmscM",
#             "plus_code": {
#                 "compound_code": "QJ63+MX Atlanta, Georgia",
#                 "global_code": "865QQJ63+MX"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJpdHfNH4E9YgRvdYHU9RmscM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 561,
#             "vicinity": "250 Park Ave W NW Ste 2, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.75488,
#                     "lng": -84.3821214
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.75622407989272,
#                         "lng": -84.38084652010728
#                     },
#                     "southwest": {
#                         "lat": 33.75352442010728,
#                         "lng": -84.38354617989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Moe's Southwest Grill",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3464,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100665317337233317641\">Papa Kilo</a>"
#                     ],
#                     "photo_reference": "Aap_uEB5uF2BKsU_oFr9EAFAOagiUujXBZ_ZwG6Vpp4cY-T_28wndEwWL0TZiFTxayvqrXgAMl1ZgpZh17kymMSch0K4JXX1wIi7y_qFgJflrSfagOJHWAwontxj_qk7YRibRqc9-vbooSPdbWu03LNLiXhYuSrxpRXtrRXZp8rI64YFMJRs",
#                     "width": 4618
#                 }
#             ],
#             "place_id": "ChIJmUfPoIkD9YgR4sOTiEDmjfw",
#             "plus_code": {
#                 "compound_code": "QJ39+X5 Atlanta, Georgia",
#                 "global_code": "865QQJ39+X5"
#             },
#             "price_level": 1,
#             "rating": 3.5,
#             "reference": "ChIJmUfPoIkD9YgR4sOTiEDmjfw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 325,
#             "vicinity": "171 Auburn Ave NE, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7606328,
#                     "lng": -84.39114939999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.76198217989271,
#                         "lng": -84.38985167010726
#                     },
#                     "southwest": {
#                         "lat": 33.75928252010727,
#                         "lng": -84.39255132989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Man vs Fries",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 832,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108314625239101880789\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBow_Vv2FODU3qDqimm59aLrIX2hA0Gt8cHpmDwRGIWPn6nh-D65GJjQp8eTDXHxtx9C9cSU4aYLNr4Ir30iv6dlM0UicHCb_PNdBp-yWIc6yDFUWeTwZwZhXWzr5qhDdAf2ItxIiVq6VX0_8p_TRByBFPqukRSp-GmXu6CV0gS8q1i",
#                     "width": 1125
#                 }
#             ],
#             "place_id": "ChIJgypVLWkF9YgRVlalEWFLWCE",
#             "plus_code": {
#                 "compound_code": "QJ65+7G Atlanta, Georgia",
#                 "global_code": "865QQJ65+7G"
#             },
#             "rating": 4.1,
#             "reference": "ChIJgypVLWkF9YgRVlalEWFLWCE",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "104 John Portman Blvd NW, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7557768,
#                     "lng": -84.3816666
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.75700912989272,
#                         "lng": -84.38033572010728
#                     },
#                     "southwest": {
#                         "lat": 33.75430947010727,
#                         "lng": -84.38303537989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Blue Cantina",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100494053421726435158\">Ameera Daboh</a>"
#                     ],
#                     "photo_reference": "Aap_uED-zEr1DI_nUtYBjrhlTHhcTsVFOM8SyuC6dwvg06hBNBl0XXaAtW9Rp3g256ML6ejkXL9nRmivYVxDh1ox0WphQ92T7PfZ5JpNAlRTQgcKZkEisgDGFR8QTkrEZDsD1lCvl7VU-bAEQSTjjGPjmL-mkZhFURITodK0Li1pb50A4EUW",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJz2LRmIkD9YgRrG4vySlxmKs",
#             "plus_code": {
#                 "compound_code": "QJ49+88 Atlanta, Georgia",
#                 "global_code": "865QQJ49+88"
#             },
#             "rating": 3.9,
#             "reference": "ChIJz2LRmIkD9YgRrG4vySlxmKs",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "186A Auburn Ave NE, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7597795,
#                     "lng": -84.38668679999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.76108112989272,
#                         "lng": -84.38540147010727
#                     },
#                     "southwest": {
#                         "lat": 33.75838147010727,
#                         "lng": -84.38810112989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Tin Lizzy's Cantina",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4514,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112840079661087995419\">Tin Lizzy&#39;s Cantina</a>"
#                     ],
#                     "photo_reference": "Aap_uEBjVcXGe5H5V-LBg4cB2XGYSaOmuUPO9gb4F1iltwvdChWxCePs55GUbhxCL5m_ulCRePvdqwxKKsNXwO2A1h5Zo77uMK2m2bQL_CSQxn_rd7xnfEg9olQdVg9CG3E0dkApXvQPJHn1dAec7j-P_G7kmaz4CLhuhasQ66S8HDxrOhHC",
#                     "width": 6764
#                 }
#             ],
#             "place_id": "ChIJEQGwSHgE9YgRMW1WQIpsLZQ",
#             "plus_code": {
#                 "compound_code": "QJ57+W8 Atlanta, Georgia",
#                 "global_code": "865QQJ57+W8"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJEQGwSHgE9YgRMW1WQIpsLZQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 911,
#             "vicinity": "26 Andrew Young International Blvd NW, Atlanta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7465236,
#                     "lng": -84.3739506
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.74794112989272,
#                         "lng": -84.37261052010727
#                     },
#                     "southwest": {
#                         "lat": 33.74524147010728,
#                         "lng": -84.37531017989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Tin Lizzy's Cantina",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111832725621203793293\">Tin Lizzys Cantina- Grant Park</a>"
#                     ],
#                     "photo_reference": "Aap_uEBiX45w8GzwqMFUO2VXI3Ol0H_LGkB8OFxApcuOFsgXXTnCvN1zwgWuz_VsvwQ5dOivrbQiYeq7pI_GMTXPqEK9dVYmoLn9tJzVcWjB4wrIZ2V-HyBMzXBTWUS1n4JzWb-8AfFPu8tPo3PNlX8hWRb_EmrgP9aSp001wnYs_2DXLFzZ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJkffaWO0D9YgR-3tjG8hG3bo",
#             "plus_code": {
#                 "compound_code": "PJWG+JC Atlanta, Georgia",
#                 "global_code": "865QPJWG+JC"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJkffaWO0D9YgR-3tjG8hG3bo",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2317,
#             "vicinity": "415 Memorial Dr SE, Atlanta"
#         }
#     ],
#     "status": "OK"
# }

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key=AIzaSyCt3iZn02ZXST9uTFioz5cxC4wp5KiXLK0"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "candidates" : [
#       {
#          "formatted_address" : "140 George St, The Rocks NSW 2000, Australia",
#          "geometry" : {
#             "location" : {
#                "lat" : -33.8599358,
#                "lng" : 151.2090295
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -33.85824377010728,
#                   "lng" : 151.2104386798927
#                },
#                "southwest" : {
#                   "lat" : -33.86094342989272,
#                   "lng" : 151.2077390201073
#                }
#             }
#          },
#          "name" : "Museum of Contemporary Art Australia",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "rating" : 4.4
#       }
#    ],
#    "status" : "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
# print(places_data["results"][0]["name"]),(places_data["results"][0]["vicinity"])
# print(places_data["results"][0]["vicinity"])
# print(places_data["results"][10]["name"])
# print(places_data["results"][10]["vicinity"])


# name = []
# rating = []
# user_ratings_total = []
# latitude = []
# longatiude = []
# business_satus = [] 
# place_id = []

# %%
# df_nested_list = pd.json_normalize(base_url, record_path =['name'])


# df = pd.read_json(base_url)
# df.head()


# build our data frame columns
name = []
rating = []
user_ratings_total = []
lat = []
lng = []
business_status = []
price_level = []

# Loop through the list of cities and perform a request for data on each
# for i, row in places_data.iterrows():
# # for restaurnts in places_data:
#     response = requests.get(base_url, params=params).json()
    
    
    
    name.append(response["results"][i]["name"])
#     rating.append(response["results"][i]["rating"])
#     user_ratings_total.append(response["results"][i]["user_ratings_total"])
#     lat.append(response["results"][i]["geometry"]["location"]["lat"])
#     lng.append(response["results"][i]["geometry"]["location"]["lng"])
#     business_status.append(response["results"][i]["business_status"])
#     price_level.append(response["results"][i]["price_level"])

#     lat.append(response['coord']['lat'])
#     temp.append(response['main']['temp'])
print(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2007d7b3f6f1> in <module>
#      16
#      17 # Loop through the list of cities and perform a request for data on each
# ---> 18 for i, row in places_data.iterrows():
#      19 # for restaurnts in places_data:
#      20     response = requests.get(base_url, params=params).json()
#
# AttributeError: 'dict' object has no attribute 'iterrows'

# %%
# atl_df=pd.DataFrame({"places_data":places_data})
# atl_df["place_id"] = ""
# atl_df["name"] = ""
# atl_df["rating"] = ""
# atl_df["user_ratings_total"] = ""
# atl_df["lat"] = ""
# atl_df["lng"] = ""
# atl_df["business_status"] = ""
# create a data frame from cities, lat, and temp
# weather_dict = {
#     "city": cities,
#     "lat": lat,
#     "temp": temp
# }
# weather_data = pd.DataFrame(weather_dict)
# weather_data.head()



# atl_dict = {
# #     "Place ID":place_id,
#     "Name":name,
#     "Rating":rating,
#     "Date":dates,
#     "User Total Rating":user_ratings_total,
#     "Latitude":lat,
#     "Longatiude":lng,
#     "Business Status":business_status,
#     "Price Level":price_level,


places_data_df=pd.DataFrame(places_data)
places_data_df.head()

# %%
url="https://api.yelp.com/v3/businesses/search?term=delis&latitude=37.786882&longitude=-122.399972"
# Make request and store response
response = requests.get(url)

# Verify status code
response.status_code
